# %%
import matplotlib
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import pandas as pd
# Out:
# C:\Users\alena\AppData\Local\Temp\ipykernel_20980\44701073.py:4: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
path = 'E:\YandexDisk/DNAm draft/map_yakutia/'
coordinates_data_path = path
coordinates_data_file = 'coordinates.xlsx'
df = pd.read_excel(f"{coordinates_data_path}/{coordinates_data_file}")
longs = df['Longitude'].values
lats = df['Latitude'].values
colors = ['xkcd:' + df['Color'].values[i] for i in range(0, len(longs))]

# %%
fig = plt.figure(figsize=(10, 5))
ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())
ax.set_global()
ax.stock_img()
ax.coastlines()
plt.scatter(x=longs,
            y=lats, 
            s=500, 
            c=colors,
            edgecolors='k',
            linewidth=1.5,
            transform=ccrs.PlateCarree())
ax.set_extent ((20, 150, 30, 83), ccrs.PlateCarree())
    
plt.savefig(f'{path}/map.png', bbox_inches='tight')
plt.savefig(f'{path}/map.pdf', bbox_inches='tight')

# %%
fig = plt.figure(figsize=(10, 5))
ax = fig.add_subplot(1, 1, 1, projection=ccrs.Orthographic(central_longitude=85.0, central_latitude=45.0, globe=None))
ax.set_global()
ax.stock_img()
ax.coastlines()
plt.scatter(x=longs,
            y=lats, 
            s=250, 
            c=colors,
            edgecolors='k',
            linewidth=1.5,
            transform=ccrs.PlateCarree())

plt.savefig(f'{path}/globe.png', bbox_inches='tight')
plt.savefig(f'{path}/globe.pdf', bbox_inches='tight')
