# %%
import pandas as pd

norm = "PBC"
path= f"D:/bioTest/attack/data"
df_pheno = pd.read_csv(f"{path}/pheno.csv", index_col=0)

# %%
df_betas = pd.read_csv(f"{path}/betas{norm}.csv", index_col=0).transpose()

# %%
df_betas = df_betas.loc[df_pheno.index.values, :]
df_betas.to_pickle(f"{path}/betas{norm}.pkl")
