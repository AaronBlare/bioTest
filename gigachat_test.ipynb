# %%
import requests

url = "https://ngw.devices.sberbank.ru:9443/api/v2/oauth"

payload={
  'scope': 'GIGACHAT_API_PERS'
}
headers = {
  'Content-Type': 'application/x-www-form-urlencoded',
  'Accept': 'application/json',
  'RqUID': '5d42fe00-efa1-4d69-aa87-0ea2a5f1e353',
  'Authorization': 'Basic NDg2NzIzOTktZTkwOC00ODdiLWJlMGEtN2M3MjNjNzU0NzE0OmRkZmY2OWJmLWY5ZmUtNGY5ZS04M2Q0LThmNGIzOWFmODM3Zg=='
}

response = requests.request("POST", url, headers=headers, data=payload)

print(response.text)

# %%
from gigachat import GigaChat

# Используйте ключ авторизации, полученный в личном кабинете, в проекте GigaChat API.
with GigaChat(credentials="NDg2NzIzOTktZTkwOC00ODdiLWJlMGEtN2M3MjNjNzU0NzE0OmRkZmY2OWJmLWY5ZmUtNGY5ZS04M2Q0LThmNGIzOWFmODM3Zg==", ca_bundle_file="C:/Users/alena/Downloads/russian_trusted_root_ca.cer") as giga:
    response = giga.chat("Какие факторы влияют на стоимость страховки на дом?")
    print(response.choices[0].message.content)
# Out:
# Стоимость страхования дома зависит от множества факторов, которые страховая компания учитывает для оценки риска и определения стоимости полиса. Вот основные из них:
#
# ### 1. **Тип недвижимости**
#    - **Размер дома**: Чем больше площадь дома, тем выше стоимость страховки. Это связано с тем, что более крупные строения требуют большего покрытия при наступлении страхового случая.
#    - **Материалы строительства**: Дома из кирпича или камня обычно стоят дороже, чем деревянные конструкции, так как они более устойчивы к пожарам и другим стихийным бедствиям.
#    - **Год постройки**: Новые дома обычно имеют меньший риск повреждений, поэтому страховка может быть дешевле. Старые здания могут требовать дополнительных проверок и иметь повышенные тарифы.
#
# ### 2. **Местоположение**
#    - **Риск стихийных бедствий**: Если дом расположен в зоне с высоким риском землетрясений, наводнений, ураганов или других природных катастроф, это увеличивает стоимость страховки.
# ...
